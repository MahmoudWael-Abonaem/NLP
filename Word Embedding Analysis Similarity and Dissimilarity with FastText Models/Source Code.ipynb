# %% [markdown]
# ### Downloading and Setting Up the  NLTK WordNet Data

# %%
import nltk
import subprocess
try:
    nltk.data.find('wordnet.zip')
except:
    nltk.download('wordnet', download_dir='/kaggle/working/')
    command = "unzip /kaggle/working/corpora/wordnet.zip -d /kaggle/working/corpora"
    subprocess.run(command.split())
    nltk.data.path.append('/kaggle/working/')

# %% [markdown]
# ### Imports and Downloads

# %%
import re
import spacy
import gensim
import random
import fasttext
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from huggingface_hub import hf_hub_download
from gensim.models.fasttext import FastText

nltk.download('punkt')
nltk.download('stopwords')

Lemmatizer = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Defining Preprocessing Functions

# %%
def Clean_Text(Text):
    Cleaned_Text = re.sub(r'[^\w\s]', '', Text)
    Cleaned_Text = re.sub(r'\d+', '', Cleaned_Text)
    Cleaned_Text = Cleaned_Text.lower()
    return Cleaned_Text

def Tokenize_Text(Text):
    tokens = word_tokenize(Text)
    return tokens

def Lemmatize_Text(tokens):
    Lemmatized_Tokens = []
    for token in tokens:
        if Lemmatizer(token)[0].lemma_ != '-PRON-':
            Lemmatized_Token = Lemmatizer(token)[0].lemma_
        else:
            Lemmatized_Token = token
        Lemmatized_Tokens.append(Lemmatized_Token)
    return Lemmatized_Tokens

def Remove_Stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    custom_stop_words = ['I']
    stop_words.update(custom_stop_words)
    filtered_tokens = [token for token in tokens if token not in stop_words]
    return filtered_tokens

# %% [markdown]
# ### Importing Yelp Dataset

# %%
# Path to Yelp Dataset
Yelp_Path = "/kaggle/input/yelp-dataset/yelp_academic_dataset_tip.json"

# Read Yelp Dataset
Yelp_Data = pd.read_json(Yelp_Path, lines=True)

# Extract the text column from the Yelp Dataset
Tip_Text = Yelp_Data['text']

# Limit the number of samples to 10,000
Sub_Tip_Text = Tip_Text[:10000]

# %% [markdown]
# ### Perform Text Preprocessing on the Extracted Text from Yelp Dataset

# %%
Filtered_Docs = []
for i in range (len(Sub_Tip_Text)):
    Cleaned_Text = Clean_Text(Sub_Tip_Text[i])
    Tokens = Tokenize_Text(Cleaned_Text)
    Lemmatized_Tokens = Lemmatize_Text(Tokens)
    Filtered_Tokens = Remove_Stopwords(Lemmatized_Tokens)
    Filtered_Words = [word for word in Filtered_Tokens if len(word) > 2] # Remove words with less than 3 characters
    Filtered_Docs.append(Filtered_Words)

# %% [markdown]
# ### Training and Saving the FastText Model

# %%
FastText_Model = FastText(sentences=Filtered_Docs, vector_size=50, window=3, min_count=3, workers=4, sg=1)
FastText_Model.save("FastText_Model")

# %% [markdown]
# ### Loading the FastText Model

# %%
FastTextModel = gensim.models.fasttext.FastText.load("FastText_Model")

# %% [markdown]
# ### Selecting 500 More Samples Randomly to Compare them With the Previous 10000 Sample

# %%
Preprocessed_Words = []
random.seed(42)
Sub_Test = random.sample(Tip_Text[10001:].tolist(), 500) # Randomly select 500 text entries (samples) from `Tip_Text` starting from entry 10001

# Perform text preprocessing on the sampled text entries
for i in range (len(Sub_Test)):
    Cleaned_Text = Clean_Text(Sub_Test[i])
    Tokens = Tokenize_Text(Cleaned_Text)
    Lemmatized_Tokens = Lemmatize_Text(Tokens)
    Filtered_Tokens = Remove_Stopwords(Lemmatized_Tokens)
    Filtered_Words = [word for word in Filtered_Tokens if len(word) > 2] # Remove words with less than 3 characters
    Preprocessed_Words.append(Filtered_Words)

# Flatten the list of sentences into a single list of words
Words = [word for sentence in Preprocessed_Words for word in sentence]
random.seed(42)
Test_Words = random.sample(Words, 50) # Randomly select 50 words from the list `Words`

# %% [markdown]
# ### Using the Trained FastText Model to Determine the Top 10 Similar and Opposite Words for Each Word

# %%
for word in Test_Words:
    print(f"Word: {(word)}")
    
    # Retrieve the top 10 most similar words
    Similar_Words = FastTextModel.wv.most_similar(positive=word, topn=10)
    print(f"\nThe top 10 similar words for the word ({word}):\n")
    for similar_word,_ in Similar_Words:
        print(similar_word)
        
    # Calculate the similarity between the target word and all other words
    similarity_scores = {w: FastTextModel.wv.similarity(word, w) for w in Test_Words if w != word}
    
    # Sort the words based on their similarity scores and select the top 10 least similar words
    Opposite_Words = sorted(similarity_scores, key=similarity_scores.get, reverse=True)[:10]
    
    print(f"\nThe top 10 opposite words for the word ({word}):\n")
    for opposite_word in Opposite_Words:
        print(opposite_word)
    
    print()
# Out:
# Word: check
#
# The top 10 similar words for the word (check):
#
# checkin
# checkout
# ticket
# cause
# case
# ill
# mill
# shake
# milkshake
# fill
#
# The top 10 opposite words for the word (check):
#
# phone
# milk
# shuffleboard
# wedding
# heck
# para
# orange
# intoxicate
# asparagus
# accolade
#
# Word: replace
#
# The top 10 similar words for the word (replace):
#
# face
# race
# seafood
# atm
# heat
# always
# pace
# real
# niece
# blood
#
# The top 10 opposite words for the word (replace):
#
# always
# beer
# place
# slice
# breast
# pizza
# amazing
# coffee
# music
# dessert
#
# Word: gmc
#
# The top 10 similar words for the word (gmc):
#
# happy
# ice
# staff
# crappy
# service
# nice
# happen
# rice
# pimms
# advice
#
# The top 10 opposite words for the word (gmc):
#
# line
# slice
# heck
# make
# take
# tre
# check
# rude
# shuffleboard
# back
#
# Word: back
#
# The top 10 similar words for the word (back):
#
# terrible
# outback
# definitely
# low
# attack
# lack
# mention
# background
# rude
# stock
#
# The top 10 opposite words for the word (back):
#
# rude
# coop
# tre
# receive
# southern
# festival
# dessert
# vegetarian
# like
# accolade
#
# Word: line
#
# The top 10 similar words for the word (line):
#
# online
# mine
# skyline
# lait
# fine
# minute
# min
# waiter
# praline
# wall
#
# The top 10 opposite words for the word (line):
#
# heck
# phone
# well
# para
# wedding
# horchata
# intoxicate
# take
# milk
# check
#
# Word: para
#
# The top 10 similar words for the word (para):
#
# par
# part
# parm
# party
# paradise
# across
# package
# pain
# path
# packet
#
# The top 10 opposite words for the word (para):
#
# phone
# wedding
# intoxicate
# milk
# asparagus
# orange
# accolade
# heck
# shuffleboard
# check
#
# Word: orange
#
# The top 10 similar words for the word (orange):
#
# range
# smoke
# change
# schedule
# difficult
# candy
# concept
# language
# basket
# concern
#
# The top 10 opposite words for the word (orange):
#
# asparagus
# accolade
# intoxicate
# shuffleboard
# milk
# tre
# vegetarian
# pickle
# southern
# downtown
#
# Word: take
#
# The top 10 similar words for the word (take):
#
# sake
# mistake
# ahead
# cake
# maker
# check
# takeout
# head
# shake
# fake
#
# The top 10 opposite words for the word (take):
#
# check
# phone
# make
# heck
# milk
# shuffleboard
# wedding
# para
# line
# orange
#
# Word: like
#
# The top 10 similar words for the word (like):
#
# feel
# different
# competent
# compliment
# consistent
# require
# likely
# hike
# convenient
# consistently
#
# The top 10 opposite words for the word (like):
#
# tre
# coop
# receive
# festival
# rude
# vegetarian
# southern
# pickle
# dessert
# orange
#
# Word: make
#
# The top 10 similar words for the word (make):
#
# take
# cake
# sake
# maker
# check
# next
# ahead
# carb
# card
# shake
#
# The top 10 opposite words for the word (make):
#
# take
# check
# heck
# phone
# milk
# para
# shuffleboard
# wedding
# line
# orange
#
# Word: pizza
#
# The top 10 similar words for the word (pizza):
#
# freshest
# amazingly
# fantastic
# grub
# ambiance
# greedy
# deliciously
# balance
# bartender
# tender
#
# The top 10 opposite words for the word (pizza):
#
# breast
# amazing
# also
# dessert
# coop
# vegetarian
# southern
# favorite
# festival
# receive
#
# Word: festival
#
# The top 10 similar words for the word (festival):
#
# delightful
# lackluster
# dental
# domestic
# easter
# release
# hipster
# industrial
# temporarily
# spectacular
#
# The top 10 opposite words for the word (festival):
#
# dessert
# receive
# downtown
# vegetarian
# intoxicate
# tre
# coop
# asparagus
# accolade
# orange
#
# Word: restaurant
#
# The top 10 similar words for the word (restaurant):
#
# summer
# rest
# permanently
# plant
# easily
# pleasant
# regularly
# hopefully
# honestly
# supreme
#
# The top 10 opposite words for the word (restaurant):
#
# festival
# receive
# downtown
# dessert
# intoxicate
# rude
# tre
# end
# asparagus
# coop
#
# Word: night
#
# The top 10 similar words for the word (night):
#
# saturday
# tuesday
# weekday
# thursday
# friday
# lay
# wednesday
# birthday
# holiday
# today
#
# The top 10 opposite words for the word (night):
#
# say
# monday
# houseless
# line
# horchata
# wedding
# phone
# intoxicate
# end
# well
#
# Word: coffee
#
# The top 10 similar words for the word (coffee):
#
# steam
# create
# crew
# creative
# crepe
# team
# lettuce
# piece
# balance
# increase
#
# The top 10 opposite words for the word (coffee):
#
# coop
# also
# breast
# dessert
# vegetarian
# pizza
# tre
# southern
# pickle
# rude
#
# Word: make
#
# The top 10 similar words for the word (make):
#
# take
# cake
# sake
# maker
# check
# next
# ahead
# carb
# card
# shake
#
# The top 10 opposite words for the word (make):
#
# take
# check
# heck
# phone
# milk
# para
# shuffleboard
# wedding
# line
# orange
#
# Word: monday
#
# The top 10 similar words for the word (monday):
#
# sunday
# bday
# today
# yay
# tuesday
# weekday
# holiday
# friday
# everyday
# saturday
#
# The top 10 opposite words for the word (monday):
#
# night
# say
# houseless
# line
# horchata
# intoxicate
# phone
# wedding
# check
# well
#
# Word: always
#
# The top 10 similar words for the word (always):
#
# seafood
# foodie
# replace
# real
# greasy
# mood
# face
# atm
# excellent
# wood
#
# The top 10 opposite words for the word (always):
#
# replace
# beer
# place
# slice
# pizza
# breast
# amazing
# music
# coffee
# also
#
# Word: slice
#
# The top 10 similar words for the word (slice):
#
# twice
# juice
# police
# spice
# notice
# office
# device
# choice
# practice
# overprice
#
# The top 10 opposite words for the word (slice):
#
# place
# replace
# always
# beer
# pizza
# coffee
# breast
# amazing
# music
# also
#
# Word: heck
#
# The top 10 similar words for the word (heck):
#
# zone
# phone
# pack
# calzone
# care
# mistake
# walkin
# wallet
# iphone
# package
#
# The top 10 opposite words for the word (heck):
#
# phone
# para
# milk
# check
# intoxicate
# shuffleboard
# asparagus
# orange
# wedding
# tre
#
# Word: beer
#
# The top 10 similar words for the word (beer):
#
# select
# pricey
# seafood
# beat
# mood
# face
# replace
# foodie
# meat
# niece
#
# The top 10 opposite words for the word (beer):
#
# replace
# always
# pizza
# music
# breast
# place
# slice
# amazing
# dessert
# also
#
# Word: milk
#
# The top 10 similar words for the word (milk):
#
# mild
# milkshake
# route
# signature
# ticket
# train
# bridge
# access
# satisfied
# boneless
#
# The top 10 opposite words for the word (milk):
#
# orange
# shuffleboard
# accolade
# phone
# asparagus
# intoxicate
# wedding
# downtown
# para
# pickle
#
# Word: favorite
#
# The top 10 similar words for the word (favorite):
#
# favor
# delta
# spanish
# fajita
# town
# various
# fave
# menus
# flavorful
# delightful
#
# The top 10 opposite words for the word (favorite):
#
# southern
# vegetarian
# dessert
# festival
# downtown
# receive
# also
# accolade
# pickle
# coop
#
# Word: accolade
#
# The top 10 similar words for the word (accolade):
#
# complimentary
# instructor
# espresso
# schedule
# trade
# shade
# provide
# bout
# strawberry
# charbroile
#
# The top 10 opposite words for the word (accolade):
#
# orange
# asparagus
# vegetarian
# intoxicate
# shuffleboard
# pickle
# southern
# downtown
# tre
# milk
#
# Word: shuffleboard
#
# The top 10 similar words for the word (shuffleboard):
#
# collard
# board
# country
# smoke
# charbroile
# military
# train
# trade
# lemonade
# bucket
#
# The top 10 opposite words for the word (shuffleboard):
#
# orange
# accolade
# intoxicate
# asparagus
# milk
# pickle
# vegetarian
# tre
# phone
# southern
#
# Word: intoxicate
#
# The top 10 similar words for the word (intoxicate):
#
# certificate
# celebrate
# accurate
# intimate
# concept
# relate
# certain
# microbrew
# skinny
# renovate
#
# The top 10 opposite words for the word (intoxicate):
#
# asparagus
# orange
# accolade
# wedding
# shuffleboard
# festival
# downtown
# phone
# milk
# receive
#
# Word: houseless
#
# The top 10 similar words for the word (houseless):
#
# hop
# hoo
# hope
# host
# honor
# hook
# flavour
# hold
# homey
# home
#
# The top 10 opposite words for the word (houseless):
#
# horchata
# downtown
# restaurant
# intoxicate
# festival
# wedding
# phone
# asparagus
# milk
# end
#
# Word: downtown
#
# The top 10 similar words for the word (downtown):
#
# natural
# november
# december
# remember
# pitcher
# desk
# sugar
# horseradish
# ownership
# celebrate
#
# The top 10 opposite words for the word (downtown):
#
# festival
# asparagus
# accolade
# orange
# intoxicate
# receive
# southern
# dessert
# vegetarian
# tre
#
# Word: horchata
#
# The top 10 similar words for the word (horchata):
#
# honest
# course
# tourist
# bourbon
# hostess
# hooter
# although
# hoagie
# without
# holder
#
# The top 10 opposite words for the word (horchata):
#
# downtown
# intoxicate
# wedding
# festival
# asparagus
# orange
# phone
# accolade
# milk
# restaurant
#
# Word: vegetarian
#
# The top 10 similar words for the word (vegetarian):
#
# italian
# asian
# port
# brazilian
# guacamole
# spanish
# ranchero
# belgian
# grocery
# bento
#
# The top 10 opposite words for the word (vegetarian):
#
# southern
# pickle
# accolade
# dessert
# tre
# orange
# festival
# asparagus
# coop
# also
#
# Word: also
#
# The top 10 similar words for the word (also):
#
# crawfish
# veggie
# relish
# banana
# flavorful
# group
# delish
# irish
# spread
# vegan
#
# The top 10 opposite words for the word (also):
#
# vegetarian
# southern
# pickle
# coop
# breast
# dessert
# amazing
# tre
# accolade
# receive
#
# Word: receive
#
# The top 10 similar words for the word (receive):
#
# informative
# positive
# alternative
# correct
# impressive
# department
# rent
# recently
# student
# complaint
#
# The top 10 opposite words for the word (receive):
#
# festival
# dessert
# tre
# rude
# southern
# downtown
# asparagus
# vegetarian
# accolade
# intoxicate
#
# Word: phone
#
# The top 10 similar words for the word (phone):
#
# iphone
# bone
# none
# cone
# calzone
# anyone
# zone
# package
# signature
# scone
#
# The top 10 opposite words for the word (phone):
#
# para
# milk
# wedding
# intoxicate
# heck
# orange
# asparagus
# shuffleboard
# check
# accolade
#
# Word: southern
#
# The top 10 similar words for the word (southern):
#
# southwest
# port
# current
# generous
# espresso
# kale
# guacamole
# vegetarian
# indiana
# challenge
#
# The top 10 opposite words for the word (southern):
#
# vegetarian
# pickle
# accolade
# asparagus
# orange
# dessert
# tre
# receive
# festival
# rude
#
# Word: amazing
#
# The top 10 similar words for the word (amazing):
#
# amazingly
# freshest
# decent
# fantastic
# deliciously
# deli
# goodness
# refresh
# nasty
# yummy
#
# The top 10 opposite words for the word (amazing):
#
# breast
# pizza
# also
# dessert
# vegetarian
# southern
# favorite
# receive
# festival
# coop
#
# Word: end
#
# The top 10 similar words for the word (end):
#
# spend
# wind
# depend
# drive
# remind
# private
# welcome
# several
# blend
# extend
#
# The top 10 opposite words for the word (end):
#
# receive
# festival
# restaurant
# dessert
# rude
# well
# intoxicate
# downtown
# coop
# tre
#
# Word: tre
#
# The top 10 similar words for the word (tre):
#
# college
# provide
# require
# concession
# important
# convenient
# bore
# report
# import
# conversation
#
# The top 10 opposite words for the word (tre):
#
# orange
# vegetarian
# rude
# coop
# receive
# southern
# dessert
# festival
# accolade
# asparagus
#
# Word: great
#
# The top 10 similar words for the word (great):
#
# food
# nice
# service
# good
# friendly
# price
# staff
# rice
# advice
# friend
#
# The top 10 opposite words for the word (great):
#
# place
# slice
# always
# replace
# beer
# pizza
# breast
# music
# amazing
# coffee
#
# Word: well
#
# The top 10 similar words for the word (well):
#
# tell
# appointment
# beverage
# welcome
# disappoint
# hell
# disappointing
# smell
# prepare
# cuisine
#
# The top 10 opposite words for the word (well):
#
# receive
# festival
# rude
# wedding
# intoxicate
# asparagus
# end
# tre
# orange
# phone
#
# Word: place
#
# The top 10 similar words for the word (place):
#
# atmosphere
# really
# device
# treat
# wood
# replace
# eat
# love
# race
# slice
#
# The top 10 opposite words for the word (place):
#
# replace
# slice
# always
# beer
# pizza
# breast
# music
# amazing
# coffee
# dessert
#
# Word: music
#
# The top 10 similar words for the word (music):
#
# basic
# bartende
# bartender
# bar
# electronic
# tender
# ambiance
# electricity
# craft
# neighborhood
#
# The top 10 opposite words for the word (music):
#
# pizza
# breast
# coop
# dessert
# amazing
# also
# rude
# vegetarian
# receive
# festival
#
# Word: asparagus
#
# The top 10 similar words for the word (asparagus):
#
# concert
# concern
# language
# schedule
# complimentary
# concession
# internet
# entertain
# certain
# messy
#
# The top 10 opposite words for the word (asparagus):
#
# orange
# accolade
# intoxicate
# southern
# downtown
# shuffleboard
# vegetarian
# wedding
# festival
# pickle
#
# Word: pickle
#
# The top 10 similar words for the word (pickle):
#
# truffle
# butter
# port
# strawberry
# charbroile
# berry
# polish
# sticky
# smoothie
# battery
#
# The top 10 opposite words for the word (pickle):
#
# vegetarian
# southern
# accolade
# orange
# shuffleboard
# asparagus
# tre
# also
# coop
# receive
#
# Word: rude
#
# The top 10 similar words for the word (rude):
#
# accessible
# uncle
# noble
# inedible
# possible
# rule
# incredible
# personality
# certainly
# convenient
#
# The top 10 opposite words for the word (rude):
#
# tre
# receive
# southern
# dessert
# coop
# festival
# accolade
# vegetarian
# orange
# asparagus
#
# Word: say
#
# The top 10 similar words for the word (say):
#
# may
# pay
# yay
# saturday
# close
# today
# weekday
# tuesday
# everyday
# lay
#
# The top 10 opposite words for the word (say):
#
# night
# monday
# houseless
# line
# horchata
# take
# check
# phone
# wedding
# milk
#
# Word: place
#
# The top 10 similar words for the word (place):
#
# atmosphere
# really
# device
# treat
# wood
# replace
# eat
# love
# race
# slice
#
# The top 10 opposite words for the word (place):
#
# replace
# slice
# always
# beer
# pizza
# breast
# music
# amazing
# coffee
# dessert
#
# Word: dessert
#
# The top 10 similar words for the word (dessert):
#
# desert
# pretzel
# security
# impressive
# healthy
# american
# pro
# possibly
# health
# consistently
#
# The top 10 opposite words for the word (dessert):
#
# festival
# receive
# vegetarian
# southern
# coop
# tre
# rude
# downtown
# accolade
# intoxicate
#
# Word: breast
#
# The top 10 similar words for the word (breast):
#
# break
# fantastic
# breakfast
# exceptionally
# grouper
# freshest
# absolutely
# balance
# nasty
# quickly
#
# The top 10 opposite words for the word (breast):
#
# amazing
# pizza
# also
# dessert
# coop
# vegetarian
# southern
# favorite
# receive
# festival
#
# Word: coop
#
# The top 10 similar words for the word (coop):
#
# cookie
# batter
# stomach
# convenient
# crazy
# increase
# completely
# american
# scoop
# already
#
# The top 10 opposite words for the word (coop):
#
# tre
# dessert
# vegetarian
# festival
# southern
# rude
# receive
# pickle
# accolade
# orange
#
# Word: wedding
#
# The top 10 similar words for the word (wedding):
#
# fitting
# willing
# sing
# topping
# dressing
# charming
# disgusting
# single
# bowling
# fucking
#
# The top 10 opposite words for the word (wedding):
#
# intoxicate
# asparagus
# phone
# orange
# para
# downtown
# accolade
# milk
# southern
# shuffleboard

# %% [markdown]
# ### Importing and Loading the Pre-trained Facebook FastText Model

# %%
model_path = hf_hub_download(repo_id="facebook/fasttext-english-nearest-neighbors", filename="model.bin")
Facebook_Model = fasttext.load_model(model_path)

# %% [markdown]
# ### Using the Pre-trained FastText Model to Determine the Top 10 Similar and Opposite Words for Each Word

# %%
for word in Test_Words:
    print(f"Word: {(word)}")
    
    # Retrieve the top 10 most similar words
    Similar_Words = Facebook_Model.get_nearest_neighbors(word, k=10)
    print(f"\nThe Top 10 Similar Words for The Word '{word}':\n")
    for similarity, similar_word in Similar_Words:
        print(similar_word)
        
    Opposite_Words = Facebook_Model.get_nearest_neighbors(word, k=len(Test_Words))
    Sorted_Opposite_Words = sorted(Opposite_Words, key=lambda x: x[0])
    print(f"\nThe Top 10 Opposite Words for The Word '{word}':\n")
    for similarity, opposite_word in Sorted_Opposite_Words[:10]:
        print(f"{opposite_word}: {similarity}")
        
    print()
# Out:
# Word: check
#
# The Top 10 Similar Words for The Word 'check':
#
# checking
# Check
# checked
# chec
# re-check
# chekc
# recheck
# double-check
# ckeck
# doublecheck
#
# The Top 10 Opposite Words for The Word 'check':
#
# checkes: 0.5088723301887512
# --check: 0.5102982521057129
# checking.: 0.5119532346725464
# Checked: 0.5119572877883911
# out.Also: 0.5133094191551208
# check.And: 0.5134046673774719
# .check: 0.5149261355400085
# CHeck: 0.5169249176979065
# check.As: 0.5181552171707153
# check.For: 0.5181910395622253
#
# Word: replace
#
# The Top 10 Similar Words for The Word 'replace':
#
# replacing
# replaced
# Replace
# repalce
# replacement
# repace
# replaces
# replce
# Replacing
# supplant
#
# The Top 10 Opposite Words for The Word 'replace':
#
# .Replace: 0.48206964135169983
# replace.I: 0.48231473565101624
# fix: 0.4883595108985901
# repla: 0.4893805980682373
# replacement.The: 0.4906591475009918
# re-engineer: 0.49219995737075806
# re-build: 0.4923125207424164
# substitute: 0.4927825629711151
# dismantle: 0.49668416380882263
# re-tool: 0.4967217743396759
#
# Word: gmc
#
# The Top 10 Similar Words for The Word 'gmc':
#
# silverado
# chevy
# f150
# chevrolet
# f-150
# f250
# z71
# f350
# f-250
# nissan
#
# The Top 10 Opposite Words for The Word 'gmc':
#
# shortbed: 0.5502447485923767
# 5.3l: 0.5511545538902283
# yukon: 0.5534526705741882
# 1500HD: 0.5543760061264038
# 4runner: 0.5546590685844421
# lebaron: 0.5558869242668152
# econoline: 0.5573011636734009
# cadilac: 0.5581263303756714
# cj7: 0.5587785840034485
# shortbox: 0.5594822764396667
#
# Word: back
#
# The Top 10 Similar Words for The Word 'back':
#
# down
# bakc
# abck
# bacl
# forth
# out
# off
# bck
# come
# back.I
#
# The Top 10 Opposite Words for The Word 'back':
#
# front: 0.49393099546432495
# back.Even: 0.49417370557785034
# bcak: 0.49453285336494446
# intot: 0.49590185284614563
# back.Since: 0.4963700473308563
# back.First: 0.497121125459671
# back.Anyway: 0.49741804599761963
# back.To: 0.49991968274116516
# off.Back: 0.5001446008682251
# back.Well: 0.5002545118331909
#
# Word: line
#
# The Top 10 Similar Words for The Word 'line':
#
# lines
# line.The
# line.This
# line.It
# line.But
# line.So
# line.When
# line.In
# line.As
# line--the
#
# The Top 10 Opposite Words for The Word 'line':
#
# demarcation: 0.5455304980278015
# lines.In: 0.550578773021698
# lines.It: 0.5512769818305969
# -line: 0.5629802346229553
# line.From: 0.5639580488204956
# line.You: 0.5680355429649353
# line.While: 0.5683913230895996
# line.Some: 0.5687365531921387
# line.Not: 0.5694190859794617
# line.One: 0.5718632340431213
#
# Word: para
#
# The Top 10 Similar Words for The Word 'para':
#
# Para
# paras
# expandir
# para.
# sub-para
# physin
# adelgazar
# etiquetas
# llevar
# experimentar
#
# The Top 10 Opposite Words for The Word 'para':
#
# levou: 0.4789745807647705
# pegar: 0.4790710508823395
# continuar: 0.48000651597976685
# subir: 0.4801301956176758
# desconectar: 0.48025888204574585
# feita: 0.48053038120269775
# sobre: 0.48181062936782837
# facilitar: 0.48181289434432983
# utilizar: 0.48294979333877563
# aqueles: 0.48415258526802063
#
# Word: orange
#
# The Top 10 Similar Words for The Word 'orange':
#
# yellow
# ornage
# purple
# organge
# tangerine
# red
# blue
# orange-
# orange-colored
# orangy
#
# The Top 10 Opposite Words for The Word 'orange':
#
# light-red: 0.5926357507705688
# yellow-orange: 0.5951830744743347
# day-glow: 0.5953713059425354
# orangey-yellow: 0.5958205461502075
# -yellow: 0.5958977341651917
# lime-green: 0.5999001264572144
# lemon: 0.601821780204773
# orangish-red: 0.6034400463104248
# orangeish: 0.6034987568855286
# red-yellow: 0.6048335433006287
#
# Word: take
#
# The Top 10 Similar Words for The Word 'take':
#
# taking
# takes
# took
# Take
# taken
# Taking
# give
# get
# tkae
# put
#
# The Top 10 Opposite Words for The Word 'take':
#
# thake: 0.4823731780052185
# .Taking: 0.4851846396923065
# atake: 0.48646625876426697
# tooks: 0.486721396446228
# on.Take: 0.4886088967323303
# out.Take: 0.48899713158607483
# relinquish: 0.48968952894210815
# take.So: 0.49268972873687744
# should: 0.49341386556625366
# try: 0.4940069317817688
#
# Word: like
#
# The Top 10 Similar Words for The Word 'like':
#
# lke
# llike
# think
# lilke
# just
# liek
# really
# feel
# something
# want
#
# The Top 10 Opposite Words for The Word 'like':
#
# sounds: 0.5351172685623169
# you: 0.5357980728149414
# amazing.If: 0.5359761714935303
# it--like: 0.5359919667243958
# say: 0.5360532402992249
# like.Anyway: 0.5365338325500488
# like.They: 0.53751540184021
# like--and: 0.539405345916748
# like.However: 0.5414984226226807
# like.Well: 0.5419914722442627
#
# Word: make
#
# The Top 10 Similar Words for The Word 'make':
#
# making
# makes
# Make
# made
# amke
# want
# sure
# create
# Making
# easier
#
# The Top 10 Opposite Words for The Word 'make':
#
# makesome: 0.49809730052948
# make.What: 0.5005066394805908
# ensure: 0.5007990002632141
# feel: 0.5015964508056641
# easer: 0.5026302337646484
# makse: 0.5041822791099548
# do: 0.504718542098999
# it.Make: 0.5050789713859558
# makig: 0.5057154297828674
# makle: 0.5070636868476868
#
# Word: pizza
#
# The Top 10 Similar Words for The Word 'pizza':
#
# pizzas
# pizza-
# Pizza
# pizza.The
# pizza.
# pizza.I
# pepperoni
# calzone
# pizzeria
# Pizzas
#
# The Top 10 Opposite Words for The Word 'pizza':
#
# focaccia: 0.5916014909744263
# apizza: 0.5926460027694702
# pizza-by-the-slice: 0.5935226082801819
# sandwich: 0.5941148996353149
# wood-oven: 0.5978356003761292
# hoagies: 0.5993521809577942
# by-the-slice: 0.6011346578598022
# meatza: 0.6022171974182129
# stone-baked: 0.6030786037445068
# pasta: 0.6038427352905273
#
# Word: festival
#
# The Top 10 Similar Words for The Word 'festival':
#
# festivals
# festival.The
# festival-
# Festival
# festival.
# festival.It
# fest
# festival.I
# fesitval
# festival.This
#
# The Top 10 Opposite Words for The Word 'festival':
#
# Folkfest: 0.5781089663505554
# festivities: 0.5782292485237122
# festivalThe: 0.5792416930198669
# Ecofest: 0.5797650218009949
# estival: 0.5850607752799988
# MayFest: 0.5873827934265137
# Streetfest: 0.5878840088844299
# FESTIVAL: 0.5889508724212646
# Positivus: 0.5892194509506226
# festival-like: 0.5896490812301636
#
# Word: restaurant
#
# The Top 10 Similar Words for The Word 'restaurant':
#
# restuarant
# eatery
# restauarant
# restaraunt
# restauraunt
# resturant
# restauant
# retaurant
# Restaurant
# resturaunt
#
# The Top 10 Opposite Words for The Word 'restaurant':
#
# bar-restaurant: 0.6566788554191589
# non-restaurant: 0.6594864726066589
# Restaraunt: 0.6597777009010315
# restarant: 0.6692453622817993
# brasserie: 0.672292947769165
# restaurnat: 0.6744277477264404
# Bistro: 0.6762744784355164
# pizzeria: 0.6764578223228455
# restaurat: 0.6771005392074585
# eaterie: 0.6787238121032715
#
# Word: night
#
# The Top 10 Similar Words for The Word 'night':
#
# nights
# evening
# nite
# night.So
# night.The
# night.This
# night.It
# night-
# night.But
# night.Also
#
# The Top 10 Opposite Words for The Word 'night':
#
# evenings: 0.6140263080596924
# night.During: 0.6161710619926453
# tonight: 0.6234040260314941
# night.All: 0.6236841082572937
# night.He: 0.6248316764831543
# night.Another: 0.6249737739562988
# nigth: 0.6270328760147095
# afternoon: 0.6271373629570007
# night.They: 0.6279757022857666
# midnight: 0.6292336583137512
#
# Word: coffee
#
# The Top 10 Similar Words for The Word 'coffee':
#
# coffe
# coffeee
# cofee
# espresso
# coffees
# cappuccino
# Coffee
# coffee-
# cofffee
# decaf
#
# The Top 10 Opposite Words for The Word 'coffee':
#
# .Coffee: 0.6203711628913879
# dark-roast: 0.6219695806503296
# coffee.When: 0.6241166591644287
# coffee.And: 0.6242457628250122
# coffee.What: 0.6246311664581299
# coffee.In: 0.6250994801521301
# Coffe: 0.6265429258346558
# Starbucks: 0.6291002035140991
# non-coffee: 0.6316540837287903
# coffie: 0.6359450221061707
#
# Word: make
#
# The Top 10 Similar Words for The Word 'make':
#
# making
# makes
# Make
# made
# amke
# want
# sure
# create
# Making
# easier
#
# The Top 10 Opposite Words for The Word 'make':
#
# makesome: 0.49809730052948
# make.What: 0.5005066394805908
# ensure: 0.5007990002632141
# feel: 0.5015964508056641
# easer: 0.5026302337646484
# makse: 0.5041822791099548
# do: 0.504718542098999
# it.Make: 0.5050789713859558
# makig: 0.5057154297828674
# makle: 0.5070636868476868
#
# Word: monday
#
# The Top 10 Similar Words for The Word 'monday':
#
# thursday
# tuesday
# friday
# wednesday
# saturday
# sunday
# thrusday
# monday-
# monday.
# wednsday
#
# The Top 10 Opposite Words for The Word 'monday':
#
# Thrusday: 0.6310486793518066
# week.: 0.6417699456214905
# tues.: 0.6424510478973389
# july: 0.6429781913757324
# fri.: 0.6438076496124268
# Thusday: 0.6457965970039368
# april: 0.6474277377128601
# december: 0.6490804553031921
# wendsday: 0.6508902907371521
# Tusday: 0.6509743928909302
#
# Word: always
#
# The Top 10 Similar Words for The Word 'always':
#
# alway
# alwasy
# ALWAYS
# never
# alwyas
# alwasys
# alsways
# really
# rarely
# often
#
# The Top 10 Opposite Words for The Word 'always':
#
# aleays: 0.5032185316085815
# hardly: 0.5057293176651001
# definitley: 0.5083528161048889
# seems: 0.5089477896690369
# alwats: 0.5132237672805786
# aalways: 0.5140872597694397
# ever: 0.5141623020172119
# whenever: 0.5150305032730103
# should: 0.5166696906089783
# slways: 0.5171664357185364
#
# Word: slice
#
# The Top 10 Similar Words for The Word 'slice':
#
# slices
# Slice
# sliced
# sliver
# slicing
# pie
# slivers
# slice.
# pie.The
# unsliced
#
# The Top 10 Opposite Words for The Word 'slice':
#
# cheesecake: 0.44448643922805786
# halves: 0.44468483328819275
# sandwich: 0.44517800211906433
# chunck: 0.44727420806884766
# dollops: 0.4478790760040283
# baquette: 0.45032116770744324
# slice-by-slice: 0.4548874795436859
# thinly-sliced: 0.45565855503082275
# piece: 0.45579034090042114
# pie-: 0.4573902189731598
#
# Word: heck
#
# The Top 10 Similar Words for The Word 'heck':
#
# hell
# geez
# HECK
# jeez
# jeeze
# hey
# yeah
# h3ll
# Geez
# guess
#
# The Top 10 Opposite Words for The Word 'heck':
#
# duh: 0.5523185133934021
# yeesh: 0.5528908967971802
# Honestly: 0.5537708401679993
# kidding: 0.556126058101654
# Jeeze: 0.558630645275116
# he11: 0.5592852830886841
# freakin: 0.5612276196479797
# darn: 0.5620527863502502
# anyways: 0.5628185868263245
# anyway: 0.563953161239624
#
# Word: beer
#
# The Top 10 Similar Words for The Word 'beer':
#
# beers
# microbrew
# lager
# beer.And
# micro-brew
# beer.So
# beer.But
# beer.The
# beer.It
# beer-
#
# The Top 10 Opposite Words for The Word 'beer':
#
# whiskey: 0.6454851031303406
# beers.I: 0.6469672322273254
# microbrewer: 0.6474709510803223
# booze: 0.6496641635894775
# beer-themed: 0.65335613489151
# brewskies: 0.6565948724746704
# craft-brewed: 0.663190484046936
# locally-brewed: 0.665158212184906
# lagers: 0.6660407781600952
# hefeweizen: 0.6664232015609741
#
# Word: milk
#
# The Top 10 Similar Words for The Word 'milk':
#
# milk.The
# milk.A
# milk.
# milk-
# milk.If
# milk.This
# milk.It
# milk.I
# milk.And
# milk.You
#
# The Top 10 Opposite Words for The Word 'milk':
#
# udder: 0.5509399771690369
# creamer: 0.5514713525772095
# mastitic: 0.5552724003791809
# buttermilk: 0.5578026175498962
# milk-producing: 0.5582982897758484
# cows: 0.5597701072692871
# whole-fat: 0.5603566765785217
# non-homogenized: 0.561416745185852
# milk-fat: 0.5617662072181702
# whey: 0.5632952451705933
#
# Word: favorite
#
# The Top 10 Similar Words for The Word 'favorite':
#
# fave
# favourite
# favortie
# all-time-favorite
# fav
# favoite
# FAVORITE
# fav.
# favority
# second-favorite
#
# The Top 10 Opposite Words for The Word 'favorite':
#
# favourte: 0.5809827446937561
# favouritest: 0.5860202312469482
# FAVE: 0.5882968902587891
# favorite.This: 0.5891177654266357
# favorites--: 0.589796781539917
# third-favorite: 0.5920748114585876
# favorites-: 0.5941855311393738
# least-favourite: 0.6000886559486389
# favoriate: 0.601850688457489
# favorite.The: 0.6040050387382507
#
# Word: accolade
#
# The Top 10 Similar Words for The Word 'accolade':
#
# plaudit
# award
# accolades
# accoladed
# awards
# plaudits
# award.This
# award.He
# award.But
# award.It
#
# The Top 10 Opposite Words for The Word 'accolade':
#
# awardsThe: 0.501507043838501
# praise: 0.5038753151893616
# commendations: 0.5062146186828613
# award.I: 0.5063938498497009
# honoured: 0.5064461827278137
# recognition: 0.5070419311523438
# lifetime-achievement: 0.5076305270195007
# deserved: 0.5091392397880554
# richly-deserved: 0.5099464058876038
# Deservedly: 0.5102924704551697
#
# Word: shuffleboard
#
# The Top 10 Similar Words for The Word 'shuffleboard':
#
# shuffleboards
# Shuffleboard
# bocce
# bocci
# foosball
# fooseball
# boccie
# billards
# billiards
# air-hockey
#
# The Top 10 Opposite Words for The Word 'shuffleboard':
#
# euchre: 0.5162779688835144
# whiffle: 0.5180539488792419
# Ping-pong: 0.5200954675674438
# pool-table: 0.5202102661132812
# Billiards: 0.5216912031173706
# regulation-sized: 0.5220469236373901
# Crokinole: 0.5226051211357117
# horseshoes: 0.5240181684494019
# petanque: 0.5249946117401123
# beer-pong: 0.5262697339057922
#
# Word: intoxicate
#
# The Top 10 Similar Words for The Word 'intoxicate':
#
# intoxicates
# stupefy
# inebriating
# inebriate
# intoxicating
# enrapture
# bewitch
# infatuate
# mesmerise
# ravish
#
# The Top 10 Opposite Words for The Word 'intoxicate':
#
# arouse: 0.48865047097206116
# titilate: 0.48908329010009766
# scintillate: 0.49006640911102295
# carouse: 0.49042725563049316
# overpower: 0.49237552285194397
# enthral: 0.49241647124290466
# befuddle: 0.4924415946006775
# captivate: 0.49499809741973877
# intoxications: 0.4953422248363495
# rouse: 0.49564144015312195
#
# Word: houseless
#
# The Top 10 Similar Words for The Word 'houseless':
#
# Houseless
# unhoused
# homeless
# shelterless
# unsheltered
# homless
# homeless.
# destitutes
# destitute
# HOMELESS
#
# The Top 10 Opposite Words for The Word 'houseless':
#
# uncared: 0.42827269434928894
# bastis: 0.4285586178302765
# panhandling: 0.4298333525657654
# wifeless: 0.4300152659416199
# half-starved: 0.43036264181137085
# vagrant: 0.43183064460754395
# micro-housing: 0.43222132325172424
# friendless: 0.4338114857673645
# Oaklanders: 0.43454068899154663
# squatters: 0.4345659911632538
#
# Word: downtown
#
# The Top 10 Similar Words for The Word 'downtown':
#
# Downtown
# dowtown
# mid-town
# downtwon
# midtown
# down-town
# uptown
# downtown-
# downtown.I
# downtown.The
#
# The Top 10 Opposite Words for The Word 'downtown':
#
# CityPlace: 0.5317621231079102
# Riverwalk: 0.5321484208106995
# west-side: 0.535193920135498
# East-side: 0.536487877368927
# westside: 0.5450358390808105
# mall: 0.5466957688331604
# Centre-ville: 0.5471507906913757
# mainstreet: 0.5479196906089783
# gastown: 0.5508397817611694
# walkable: 0.5511824488639832
#
# Word: horchata
#
# The Top 10 Similar Words for The Word 'horchata':
#
# Horchata
# champurrado
# licuados
# tepache
# elote
# pozole
# michelada
# rompope
# sangria
# churros
#
# The Top 10 Opposite Words for The Word 'horchata':
#
# birria: 0.56576007604599
# margarita: 0.5659418106079102
# coquito: 0.5662071704864502
# cerveza: 0.5671007633209229
# cervesa: 0.5685423612594604
# elotes: 0.5687863230705261
# natilla: 0.5697380304336548
# chufa: 0.5699418783187866
# tostadas: 0.5710858702659607
# jugos: 0.5712160468101501
#
# Word: vegetarian
#
# The Top 10 Similar Words for The Word 'vegetarian':
#
# vegan
# vegeterian
# vegetarians
# meat-free
# vegitarian
# vegatarian
# vegetarian-
# non-vegetarian
# lacto-vegetarian
# Vegetarian
#
# The Top 10 Opposite Words for The Word 'vegetarian':
#
# vegeterians: 0.6365208625793457
# non-vegetarians: 0.6368484497070312
# all-veggie: 0.6380701065063477
# all-vegan: 0.638279378414154
# non-veg: 0.6390208601951599
# raw-vegan: 0.639697253704071
# plant-based: 0.6406174302101135
# lacto-ovo-vegetarian: 0.6417468786239624
# vegan.I: 0.6423502564430237
# nonvegan: 0.6429463028907776
#
# Word: also
#
# The Top 10 Similar Words for The Word 'also':
#
# alos
# aslo
# additionally
# likewise
# may
# which
# have
# always
# certainly
# has
#
# The Top 10 Opposite Words for The Word 'also':
#
# noted: 0.4972972571849823
# normally: 0.4986073076725006
# furthermore: 0.49865856766700745
# meanwhile: 0.4989796578884125
# still: 0.49940234422683716
# typically: 0.5010339021682739
# alsp: 0.5014020800590515
# in-turn: 0.5021929144859314
# nevertheless: 0.5028501749038696
# been: 0.5052573084831238
#
# Word: receive
#
# The Top 10 Similar Words for The Word 'receive':
#
# recieve
# receiving
# receives
# received
# Receive
# receieve
# send
# receie
# eceive
# receivee
#
# The Top 10 Opposite Words for The Word 'receive':
#
# submit: 0.46247124671936035
# recieveing: 0.4631263315677643
# sends: 0.4639439284801483
# pay: 0.46408987045288086
# participate: 0.46727025508880615
# receive.: 0.47145378589630127
# withhold: 0.47193363308906555
# re-ceived: 0.47418415546417236
# sent: 0.4778018891811371
# transmit: 0.48477795720100403
#
# Word: phone
#
# The Top 10 Similar Words for The Word 'phone':
#
# cellphone
# phones
# phone.Now
# phone.And
# phone.When
# phone.That
# phone.So
# cell-phone
# phone.It
# phone.The
#
# The Top 10 Opposite Words for The Word 'phone':
#
# cell: 0.6111950874328613
# phone.How: 0.6112848520278931
# phone.With: 0.6136001944541931
# fone: 0.6137894988059998
# speakerphone: 0.6147639155387878
# phone.Here: 0.6220957636833191
# phones.I: 0.6242393851280212
# aphone: 0.6288593411445618
# Phone: 0.6331722736358643
# voicemail: 0.6354169249534607
#
# Word: southern
#
# The Top 10 Similar Words for The Word 'southern':
#
# northern
# eastern
# northeastern
# southwestern
# southeastern
# northwestern
# souther
# south-eastern
# north-eastern
# western
#
# The Top 10 Opposite Words for The Word 'southern':
#
# non-southern: 0.5941585302352905
# central-south: 0.5946148633956909
# easternmost: 0.5954753160476685
# South-western: 0.5970781445503235
# south-west: 0.598013699054718
# sothern: 0.5999420881271362
# North-eastern: 0.602221667766571
# central-eastern: 0.6052052974700928
# north-east: 0.6059954762458801
# central-east: 0.6090815663337708
#
# Word: amazing
#
# The Top 10 Similar Words for The Word 'amazing':
#
# incredible
# awesome
# fantastic
# AMAZING
# wonderful
# amzing
# INCREDIBLE
# unbelievable
# phenomenal
# fabulous
#
# The Top 10 Opposite Words for The Word 'amazing':
#
# amaziing: 0.633881688117981
# superb: 0.6350845694541931
# wonderul: 0.6354355812072754
# incrediable: 0.6378611326217651
# incredble: 0.6380724310874939
# amazing-: 0.6418144702911377
# fanastic: 0.6431813836097717
# incredable: 0.6432139873504639
# fantastically: 0.643754780292511
# amaizng: 0.6489434242248535
#
# Word: end
#
# The Top 10 Similar Words for The Word 'end':
#
# beginning
# ends
# ending
# end.At
# end.In
# end.This
# end.The
# mid-point
# end.After
# end.As
#
# The Top 10 Opposite Words for The Word 'end':
#
# end.Another: 0.4835159182548523
# penultimate: 0.4837627410888672
# end.Then: 0.48445436358451843
# remainder: 0.48451268672943115
# end.To: 0.48824065923690796
# begininng: 0.4886325001716614
# end.Now: 0.488969624042511
# end--: 0.4903218448162079
# end.On: 0.4904622435569763
# endof: 0.4915732443332672
#
# Word: tre
#
# The Top 10 Similar Words for The Word 'tre':
#
# te
# che
# tes
# mendous
# tardi
# tette
# vanno
# taire
# eroe
# sto
#
# The Top 10 Opposite Words for The Word 'tre':
#
# giù: 0.5376575589179993
# acque: 0.5379015803337097
# miste: 0.5381113290786743
# ge: 0.5384291410446167
# cerchi: 0.5400145053863525
# si: 0.5402337312698364
# prende: 0.5404573678970337
# dimensioni: 0.540711522102356
# rou: 0.5408329963684082
# tetti: 0.5421583652496338
#
# Word: great
#
# The Top 10 Similar Words for The Word 'great':
#
# fantastic
# terrific
# wonderful
# good
# geat
# excellent
# amazing
# tremendous
# nice
# awesome
#
# The Top 10 Opposite Words for The Word 'great':
#
# terrifc: 0.5484104156494141
# greaat: 0.549813449382782
# greatt: 0.5498311519622803
# gerat: 0.5512707829475403
# awsome: 0.552011251449585
# gread: 0.5538777709007263
# amzing: 0.5555859804153442
# FANTASTIC: 0.5559083223342896
# trememdous: 0.5585955381393433
# fatastic: 0.5596301555633545
#
# Word: well
#
# The Top 10 Similar Words for The Word 'well':
#
# well-
# nicely
# as
# well.As
# welll
# well.I
# well.So
# well.Well
# well.The
# excellently
#
# The Top 10 Opposite Words for The Word 'well':
#
# such: 0.5288993716239929
# well--but: 0.529875636100769
# well.Even: 0.5301330089569092
# far: 0.5302969217300415
# well.Second: 0.5310829877853394
# well.He: 0.5321068167686462
# reasonably: 0.5361468195915222
# quite: 0.5371783375740051
# well.Everything: 0.5373603701591492
# well.Having: 0.537962019443512
#
# Word: place
#
# The Top 10 Similar Words for The Word 'place':
#
# palce
# places
# place.This
# place.The
# plce
# place.It
# place--the
# place-
# plac
# place--and
#
# The Top 10 Opposite Words for The Word 'place':
#
# place.When: 0.4659090042114258
# place.First: 0.4666634798049927
# place.That: 0.4679211378097534
# place.Its: 0.4680749773979187
# olace: 0.4705571234226227
# place.To: 0.47142937779426575
# place.But: 0.4726470112800598
# place.All: 0.4727812111377716
# stay: 0.4752652645111084
# place.From: 0.475388765335083
#
# Word: music
#
# The Top 10 Similar Words for The Word 'music':
#
# musics
# muisc
# music.This
# music.
# music.The
# music.It
# music.But
# music.Music
# music-
# music.Now
#
# The Top 10 Opposite Words for The Word 'music':
#
# music.2.: 0.600943922996521
# soundtrack: 0.6022171974182129
# music.A: 0.6030288934707642
# musicand: 0.6078999042510986
# music.From: 0.6084447503089905
# msuic: 0.608496367931366
# music.We: 0.6098044514656067
# music.To: 0.6101208925247192
# music--and: 0.610927164554596
# music.After: 0.6113015413284302
#
# Word: asparagus
#
# The Top 10 Similar Words for The Word 'asparagus':
#
# aspargus
# Asparagus
# broccoli
# broccolini
# leeks
# artichokes
# asparagas
# kohlrabi
# radishes
# spinach
#
# The Top 10 Opposite Words for The Word 'asparagus':
#
# radish: 0.5806607604026794
# edamame: 0.5828229784965515
# risotto: 0.5859662294387817
# agretti: 0.5887829065322876
# cauliflowers: 0.5896410942077637
# artichoke: 0.5910193920135498
# sprouts: 0.5912614464759827
# broccolis: 0.5915985107421875
# tarragon: 0.5940955281257629
# cardoons: 0.5951425433158875
#
# Word: pickle
#
# The Top 10 Similar Words for The Word 'pickle':
#
# pickles
# pickling
# pickel
# gherkins
# pickled
# dills
# gherkin
# half-sour
# chutney
# sauerkraut
#
# The Top 10 Opposite Words for The Word 'pickle':
#
# pickeled: 0.49079662561416626
# vinegary: 0.49270203709602356
# tsukemono: 0.4951993227005005
# watermelon: 0.4959407448768616
# pickle-flavored: 0.4978623688220978
# kimchee: 0.4985375702381134
# horse-radish: 0.4991179406642914
# jalapeno: 0.4991209805011749
# cucmber: 0.4996950626373291
# tomato: 0.5000348091125488
#
# Word: rude
#
# The Top 10 Similar Words for The Word 'rude':
#
# impolite
# unpolite
# disrespectful
# rude.
# RUDE
# rude-
# condescending
# inconsiderate
# ill-mannered
# rude.I
#
# The Top 10 Opposite Words for The Word 'rude':
#
# uncourteous: 0.5896228551864624
# insensitive: 0.5899757742881775
# Disrespectful: 0.590000569820404
# disrespectfull: 0.5954576134681702
# dickish: 0.5961549282073975
# impolitely: 0.5963886380195618
# crass: 0.5986371040344238
# snotty: 0.5991068482398987
# boorish: 0.6021445393562317
# unprofessional.: 0.6051613688468933
#
# Word: say
#
# The Top 10 Similar Words for The Word 'say':
#
# know
# think
# believe
# tell
# say.And
# saying
# argue
# guess
# suppose
# presume
#
# The Top 10 Opposite Words for The Word 'say':
#
# say.The: 0.557169497013092
# say.Then: 0.5583265423774719
# hear: 0.5587642192840576
# say.But: 0.5588861107826233
# what: 0.5611840486526489
# say.Anyway: 0.5619309544563293
# say.: 0.5632801055908203
# agree.So: 0.5645018815994263
# say.They: 0.5649535655975342
# assume: 0.5656479597091675
#
# Word: place
#
# The Top 10 Similar Words for The Word 'place':
#
# palce
# places
# place.This
# place.The
# plce
# place.It
# place--the
# place-
# plac
# place--and
#
# The Top 10 Opposite Words for The Word 'place':
#
# place.When: 0.4659090042114258
# place.First: 0.4666634798049927
# place.That: 0.4679211378097534
# place.Its: 0.4680749773979187
# olace: 0.4705571234226227
# place.To: 0.47142937779426575
# place.But: 0.4726470112800598
# place.All: 0.4727812111377716
# stay: 0.4752652645111084
# place.From: 0.475388765335083
#
# Word: dessert
#
# The Top 10 Similar Words for The Word 'dessert':
#
# desserts
# dessert-
# Dessert
# dessert.This
# dessert.The
# tiramisu
# cheesecake
# dessert.I
# dessert.
# non-dessert
#
# The Top 10 Opposite Words for The Word 'dessert':
#
# cheescake: 0.5745031833648682
# snack: 0.5753299593925476
# chocolate-raspberry: 0.5776285529136658
# pudding: 0.5781657099723816
# mignardises: 0.5807536244392395
# desserts.: 0.5808099508285522
# sundae: 0.5812801122665405
# mini-cheesecakes: 0.5838703513145447
# cheesecake-like: 0.584343433380127
# mini-cake: 0.5861636400222778
#
# Word: breast
#
# The Top 10 Similar Words for The Word 'breast':
#
# Breast
# breast-
# breasts
# breast.
# breats
# non-breast
# breas
# breast-cancer
# breat
# brest
#
# The Top 10 Opposite Words for The Word 'breast':
#
# triple-negative: 0.5095540285110474
# self-breast: 0.5112742781639099
# boobie: 0.5140683054924011
# cervical: 0.514687180519104
# lumpectomy: 0.5172368884086609
# fibroadenomas: 0.5187239050865173
# breasts.I: 0.5201402902603149
# boobs: 0.522980809211731
# breasts.The: 0.5247771143913269
# ductal: 0.5265700817108154
#
# Word: coop
#
# The Top 10 Similar Words for The Word 'coop':
#
# coops
# coop.
# chickens
# brooder
# co-op
# henhouse
# eglu
# hen-house
# henhouses
# hens
#
# The Top 10 Opposite Words for The Word 'coop':
#
# serama: 0.47054532170295715
# silkie: 0.4709056317806244
# cochins: 0.47526779770851135
# nest.The: 0.47715631127357483
# roosting: 0.47715845704078674
# cooping: 0.47778838872909546
# poults: 0.47807738184928894
# chooks: 0.4783160984516144
# chicken-raising: 0.4801095724105835
# brooders: 0.4829915165901184
#
# Word: wedding
#
# The Top 10 Similar Words for The Word 'wedding':
#
# weddding
# bridal
# wedding-
# weddings
# wedding.This
# Wedding
# wedding.The
# weding
# wedding.
# non-wedding
#
# The Top 10 Opposite Words for The Word 'wedding':
#
# -Wedding: 0.6058757901191711
# weddings.: 0.6102235317230225
# weddings.I: 0.6143699884414673
# nuptuals: 0.6200851202011108
# wedding-themed: 0.6204046607017517
# weddingI: 0.6204817295074463
# groomsman: 0.6211571097373962
# bridemaid: 0.6227679252624512
# bridemaids: 0.6294009685516357
# wedd: 0.6396740674972534
